# %% [markdown]
# <a href="https://colab.research.google.com/github/badrinarayanms/ml/blob/main/Recource.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/datacomp.csv')

# %%
data.head()
# Out:
#            Name       Team  ...    Experience                  Past Contributions
# 0   Arjun Gupta       Tech  ...      Advanced      Developed a chatbot for events
# 1    Meera Nair       Tech  ...  Intermediate          Conducted coding workshops
# 2  Rohan Sharma       Tech  ...      Beginner              Designed event posters
# 3  Anjali Menon  Creatives  ...  Intermediate          Created promotional videos
# 4  Karthik Iyer  Creatives  ...      Advanced  Covered live events through photos
#
# [5 rows x 6 columns]

# %%
mlb_skills = MultiLabelBinarizer()
mlb_interests = MultiLabelBinarizer()

# %% [markdown]
# # Split skills and interests into lists

# %%
data['Skills'] = data['Skills'].apply(lambda x: x.split(', ') if x != '' else [])
data['Interests'] = data['Interests'].apply(lambda x: x.split(', ') if x != '' else [])

# %% [markdown]
# # Apply MultiLabelBinarizer to encode skills and interests into binary columns

# %%
skills_encoded = mlb_skills.fit_transform(data['Skills'])
interests_encoded = mlb_interests.fit_transform(data['Interests'])

# %% [markdown]
# # Convert the encoded skills and interests into DataFrames

# %%
skills_encoded = mlb_skills.fit_transform(data['Skills'])
interests_encoded = mlb_interests.fit_transform(data['Interests'])

# %% [markdown]
# #convert encoded array to df

# %%
skills_df = pd.DataFrame(skills_encoded, columns=mlb_skills.classes_)
interests_df = pd.DataFrame(interests_encoded, columns=mlb_interests.classes_)

# %%
data = pd.concat([data, skills_df, interests_df], axis=1)
data.head()
# Out:
#            Name       Team  ... Web Development Writing Blogs
# 0   Arjun Gupta       Tech  ...               1             0
# 1    Meera Nair       Tech  ...               0             0
# 2  Rohan Sharma       Tech  ...               0             0
# 3  Anjali Menon  Creatives  ...               0             0
# 4  Karthik Iyer  Creatives  ...               0             0
#
# [5 rows x 74 columns]

# %% [markdown]
# #copy of data

# %%
data_combined = data.copy()

# %% [markdown]
# #combine all duplicates

# %%
# Check for duplicate column names
print(data_combined.columns[data_combined.columns.duplicated()])
# Out:
# Index(['Illustrations', 'Problem-Solving', 'Public Speaking'], dtype='object')

# %%
data_combined['Illustrations'] = data_combined['Illustrations'] + data_combined['Illustrations']  # Combine duplicates
data_combined['Public Speaking'] = data_combined['Public Speaking'] + data_combined['Public Speaking']  # Combine duplicates
data_combined['Problem-Solving'] = data_combined['Problem-Solving'] + data_combined['Problem-Solving']  # Combine duplicates

# %%
data_combined.head()
# Out:
#            Name       Team  ... Web Development Writing Blogs
# 0   Arjun Gupta       Tech  ...               1             0
# 1    Meera Nair       Tech  ...               0             0
# 2  Rohan Sharma       Tech  ...               0             0
# 3  Anjali Menon  Creatives  ...               0             0
# 4  Karthik Iyer  Creatives  ...               0             0
#
# [5 rows x 74 columns]

# %%
# Check for duplicate column names
print(data_combined.columns[data_combined.columns.duplicated()])
# Out:
# Index(['Illustrations', 'Problem-Solving', 'Public Speaking'], dtype='object')

# %%
data_combined['UI/UX Design'] = data_combined['UI Design'] + data_combined['UI/UX Design'] + data_combined['UI/UX'] + data_combined['Designing Apps']  + data_combined['Photoshop'] + data_combined['Illustrations'] + data_combined['Figma'] + data_combined['Canva'] + data_combined['Lightroom']
data_combined['Design'] = data_combined['Designing']
data_combined['Problem-Solving'] = data_combined['Problem-Solving'] + data_combined['Critical Thinking'] + data_combined['Data Structures']
data_combined['Photography'] = data_combined['Photography'] + data_combined['Travel Photography']
data_combined['Content Writing'] = data_combined['Content Writing'] + data_combined['Writing Blogs']
data_combined['Leadership'] = data_combined['Leadership'] + data_combined['Team Leadership']
data_combined['Event Management'] = data_combined['Event Management'] + data_combined['Organizing Events'] + data_combined['Event Coordination']
data_combined['Public Speaking'] = data_combined['Public Speaking'] + data_combined['Speech Writing']
data_combined['Video Editing'] = data_combined['Video Editing'] + data_combined['Adobe Premiere Pro']
data_combined = data_combined.drop(columns=['UI Design', 'UI/UX','Designing Apps','Designing','Critical Thinking','Travel Photography',
                                            'Writing Blogs','Team Leadership','Organizing Events', 'Event Coordination','Speech Writing','Data Structures','Adobe Premiere Pro','Photoshop','Illustrations','Figma','Canva','Lightroom'])
